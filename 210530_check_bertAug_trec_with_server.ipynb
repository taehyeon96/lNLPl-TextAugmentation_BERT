# %%
# !pwd
# Out:
# /home/user/Tae_StudyCode

# %%
# %cd TransformersDataAugmentation/src/utils/datasets/trec
# Out:
# /home/user/Tae_StudyCode/TransformersDataAugmentation/src/utils/datasets/trec

# %%
import pandas as pd

raw_dataset = pd.read_csv("train.tsv", delimiter='\t')
raw_dataset
# Out:
#           Numeric                      How long is human gestation ?
# 0           Human  Who is known as `` the world 's oldest teenage...
# 1        Location           What is George Lucas 's e-mail address ?
# 2     Description         What are Cushman and Wakefield known for ?
# 3         Numeric  How many states did Richard Nixon carry in 1972 ?
# 4     Description    How does the tail affect the flight of a kite ?
# ...           ...                                                ...
# 4900     Location                      Where is the Keck telescope ?
# 4901     Location  What country did the Allies invade in World Wa...
# 4902  Description  What are those little blue reflectors in the m...
# 4903  Description  What would happen to Canada if Quebec separated ?
# 4904        Human           Who are the Challengers of the Unknown ?
#
# [4905 rows x 2 columns]

# %%
''' exp_0_10 dataset '''
raw_dataset_0to10 = pd.read_csv("exp_0_10/train.tsv", delimiter='\t')
raw_dataset_0to10
# Out:
#          numeric         what is columbia tristar 's phone number ?
# 0        numeric                how big is our galaxy in diameter ?
# 1        numeric  what is the most number of goals scored by a s...
# 2        numeric            how many varieties of apple are there ?
# 3        numeric             what year did montana become a state ?
# 4        numeric  how many lawyers are there in the state of new...
# 5        numeric    what chapter of the bible has the most verses ?
# 6        numeric              what is dick clark 's date of birth ?
# 7        numeric                               when is boxing day ?
# 8        numeric                        when is the thai new year ?
# 9          human                   who invented `` the muppets '' ?
# 10         human  what two commanders directed the forces in the...
# 11         human  who was the first elected mayor of washington ...
# 12         human  who played sally rogers on the dick van dyke s...
# 13         human  what apollo 11 astronaut minded the store whil...
# 14         human  who manufactures the software , `` photoshop '' ?
# 15         human  who was scrooge 's dead partner in dickens 's ...
# 16         human  who was the mother of the man who would not be...
# 17         human     who awarded the flying fickle finger of fate ?
# 18         human  what 's the middle name of movie producer jose...
# 19      location            where is one 's corpus callosum found ?
# 20      location   what caribbean island is northeast of trinidad ?
# 21      location             what city is found in the city of oz ?
# 22      location   what 's the fifth-largest country in the world ?
# 23      location  where does the weird shape of the dinner fish ...
# 24      location  what is the name of the planet that the ewoks ...
# 25      location  what asian gulf were the destroyers maddox and...
# 26      location  what u.s. city is known as the rubber capital ...
# 27      location  what country is the setting for edgar allan po...
# 28      location  what country boasts cawdor castle , glamis cas...
# 29   description                      what is thermal equilibrium ?
# 30   description  how did the hohenzollerns build their power ar...
# 31   description                         what happened to pompeii ?
# 32   description                             what is home banking ?
# 33   description                          what is an urban legend ?
# 34   description  what was al capone finally imprisoned for , in...
# 35   description                            how do birds have sex ?
# 36   description  what was the v-8 juice slogan : `` the tastebu...
# 37   description                 why are there olives in martinis ?
# 38   description  what is the history of spartacus , the roman s...
# 39        entity  what kind of patent did ermal fraze get in 1963 ?
# 40        entity       which ear can most people hear better with ?
# 41        entity  name the french historical period during the r...
# 42        entity           what determines the value of the pearl ?
# 43        entity         what language is mostly spoken in brazil ?
# 44        entity  what is the lens behind the iris in the eye ca...
# 45        entity                     what are halloween 's colors ?
# 46        entity     in beetle bailey , can you name sarge 's dog ?
# 47        entity  what fastener did whitcomb judson patent in 18...
# 48        entity  what game do steve mcqueen and edward g. robin...
# 49  abbreviation                 what is the full name of the plo ?
# 50  abbreviation                                      what is dsl ?
# 51  abbreviation                         what does nasa stand for ?
# 52  abbreviation                          what does ekg stand for ?
# 53  abbreviation                    what does `` b.y.o.b. '' mean ?
# 54  abbreviation  what is the abbreviated form of the national b...
# 55  abbreviation                          what does bud stand for ?
# 56  abbreviation  what is p.m. an abbreviation for , as in 5 p.m. ?
# 57  abbreviation  what is the abbreviation of the company name `...
# 58  abbreviation                        what does nafta stand for ?

# %% [markdown]
# ### 각각의 bert로 augmentation한 결과
# - cbert
# - cmobert
# - cmobertp

# %%
''' cbert 결과 '''
cbert_dataset_0to10 = pd.read_csv("exp_0_10/cbert/cbert_aug.tsv", delimiter='\t')
cbert_dataset_0to10
# Out:
#          numeric        what is columbia tristar ' s phone number ?
# 0        numeric                how big is our galaxy in diameter ?
# 1        numeric  what is the most number of goals scored by a s...
# 2        numeric            how many varieties of apple are there ?
# 3        numeric             what year did montana become a state ?
# 4        numeric  how many kids are musicians in the state of ne...
# 5        numeric       what book of the bible has the most verses ?
# 6        numeric               what is dickburn ' s date of birth ?
# 7        numeric                               when is boxing day ?
# 8        numeric                        when is the thai new year ?
# 9          human             who invented ` ` the muppet show ' ' ?
# 10         human  what two commanders directed the forces in the...
# 11         human  when was the first elected mayor of washington...
# 12         human  who played sally rogers on the dick van dyke s...
# 13         human  what apollo 11 astronaut minded the store whil...
# 14         human  who manufactures the software for ` ` photosho...
# 15         human  who was scrooge ' s literary partner in dicken...
# 16         human  who was the mother of the man who actually not...
# 17         human     who awarded the flying fickle finger of fate ?
# 18         human  what ' s the middle name of movie producer jos...
# 19      location           where is one ' s corpus callosum found ?
# 20      location       what small island is northeast of trinidad ?
# 21      location             what city is found in the city of oz ?
# 22      location   what ' s the fifth - largest city in the world ?
# 23      location  where does the weird shape of the dinner fish ...
# 24      location  what is the name of the town that the ewoks li...
# 25      location  which asian gulf were the destroyers maddox an...
# 26      location  what u . s . city is known as the rubber capit...
# 27      location  what country is the setting for edgar allan po...
# 28      location  what country boasts cawdor castle , glampo cas...
# 29   description                             what is thermal rock ?
# 30   description  how did the hohenzollerns build their power ar...
# 31   description                         what happened to pompeii ?
# 32   description                                 what is home for ?
# 33   description                         what is an urban ecology ?
# 34   description   what was al caponeone imprisoned for , in 1931 ?
# 35   description                            how do birds have sex ?
# 36   description  what was the v - 8 juice slogan : ` ` the tast...
# 37   description                  why are there lime in martiniss ?
# 38   description  what is the history of spartacus , the trade s...
# 39        entity  what kind of patent did ermal coze hold in 1963 ?
# 40        entity       which ear can most people hear better with ?
# 41        entity  about the french historical period during the ...
# 42        entity           what determines the value of the pearl ?
# 43        entity         what language is mostly spoken in brazil ?
# 44        entity  what is the lens behind the iris in the eye ca...
# 45        entity                    what are halloween ' s colors ?
# 46        entity    in beetle bailey , can you name sarge ' s dog ?
# 47        entity  what sweetener did whitcomb judson patent in 1...
# 48        entity  what game do steve mcqueen and edward g . robi...
# 49  abbreviation                 what is the full name of the plo ?
# 50  abbreviation                                      what is dsl ?
# 51  abbreviation                         what does nasa stand for ?
# 52  abbreviation               what does ek philippines stand for ?
# 53  abbreviation           what does ` ' b . y . o . c . ' ' mean ?
# 54  abbreviation  what is the abbreviated form of the national b...
# 55  abbreviation                          what does bud stand for ?
# 56  abbreviation  what is o . m . an abbreviation for , as in 5 ...
# 57  abbreviation  what is the source of the company name ` gener...
# 58  abbreviation                        what does nafta stand for ?

# %%
''' c mod bert (= Bert Only MLM) 결과 '''
cmodbert_dataset_0to10 = pd.read_csv("exp_0_10/cmodbert/cmodbert_aug.tsv", delimiter='\t')
cmodbert_dataset_0to10
# Out:
#          numeric        what is columbia tristar ' s phone number ?
# 0        numeric               what big is our galaxy in diameter ?
# 1        numeric  what is the statesman number of goals scored b...
# 2        numeric            how many varieties of apple are there ?
# 3        numeric             what year did stocked become a state ?
# 4        numeric  how many lawyers are there the the state of ne...
# 5        numeric  what chapter losses the bible has the most ver...
# 6        numeric             what is dick clark ' s date of birth ?
# 7        numeric                               what is boxing day ?
# 8        numeric                        what is the thai new year ?
# 9          human                 who invented ` ` the muppets ' ' ?
# 10         human  whatuted commanders directed the forceseyer th...
# 11         human  who was the first elected mayor of washington ...
# 12         human  who played sally rogers on the dick van stamme...
# 13         human  what apollo 11 astronaut mindedcked store whil...
# 14         human  who manufactures the software , ` ` photoshop ...
# 15         human  who was scrooge ' s dead partner in dickens ' ...
# 16         human  who was the mother of the man who would not be...
# 17         human     who awarded the flying fickle finger of fate ?
# 18         human  what ' s the middle name of movie producer jos...
# 19      location         where is one ' s corpus callos the found ?
# 20      location         what the island is northeast of trinidad ?
# 21      location            what city is laurel in the city of oz ?
# 22      location  what ' s the fifth - largest country in the wo...
# 23      location  where does the tong shape of the the fish knif...
# 24      location  what what the name of the planet that the ewok...
# 25      location  what asian gulf were the destroyers maddox and...
# 26      location  what u . s . city is known as theا capital of ...
# 27      location  what country is the setting for edgar allan po...
# 28      location  what country muller cawdor castle , glamis cas...
# 29   description                      what is thermal equilibrium ?
# 30   description  how did the ho 01zollerns build their power ar...
# 31   description                         what happened to pompeii ?
# 32   description                            pepsi is home banking ?
# 33   description                              what is an urban is ?
# 34   description  what marcus al capone finally imprisoned for ,...
# 35   description                           how do birds have from ?
# 36   description  what was the v - 8 juice slogan : ` ` the tast...
# 37   description                 why are there olive in martiniss ?
# 38   description  what average the history of spartacus , the ro...
# 39        entity  what kind of patent did ermal ʰze jewelry in 1...
# 40        entity       which ear can most people hear better with ?
# 41        entity  name the french in period during the reign of ...
# 42        entity       what determines the value of the plausible ?
# 43        entity         what language is mostly spoken in brazil ?
# 44        entity  what is the lens behind the iris in the eye ca...
# 45        entity                    what are halloween ' s colors ?
# 46        entity  in beetle wellington , can you name sarge ' s ...
# 47        entity    in fastener in whitcomb judson patent in 1893 ?
# 48        entity  what game do steve mcqueen and edward g . robi...
# 49  abbreviation               what is the fullurities of the plo ?
# 50  abbreviation                               what is ds stadium ?
# 51  abbreviation                           what does nasa stand ি ?
# 52  abbreviation                          what does ekg stand for ?
# 53  abbreviation            what does ` `f . y . o . b . ' ' mean ?
# 54  abbreviation  what is the abbreviatedper of the national bur...
# 55  abbreviation                          what does bud stand for ?
# 56  abbreviation  what is p . older . an abbreviation for , as i...
# 57  abbreviation  what is the abbreviation for the company name ...
# 58  abbreviation                what does naft released stand for ?

# %%
''' c mod bert p (= Bert MLM + NSM) 결과 '''
cmodbertp_dataset_0to10 = pd.read_csv("exp_0_10/cmodbertp/cmodbertp_aug.tsv", delimiter='\t')
cmodbertp_dataset_0to10
# Out:
#          numeric        what is columbia tristar ' s phone number ?
# 0        numeric                how big is our galaxy in diameter ?
# 1        numeric  what is the average number of goals scored by ...
# 2        numeric            how many varieties of apple are there ?
# 3        numeric             what year did montana become a state ?
# 4        numeric  how many lawyers are there in the state of new...
# 5        numeric    what chapter in the bible has the most verses ?
# 6        numeric             what is dick clark ' s date of birth ?
# 7        numeric                               what is boxing day ?
# 8        numeric                        what is the thai new year ?
# 9          human                 who invented ` ` the muppets ' ' ?
# 10         human  what how commanders directed the forces during...
# 11         human  who was the first elected mayor of washington ...
# 12         human  who played sally rogers on the dick van dyke s...
# 13         human  what apollo 11 astronaut minded in store while...
# 14         human  who manufactures the software , ` ` photoshop ...
# 15         human  who was scrooge ' s dead partner in dickens ' ...
# 16         human  who was the mother of the man who would not be...
# 17         human   being awarded the flying fickle finger of fate ?
# 18         human  what ' s the middle name of movie producer jos...
# 19      location           where is one ' s corpus callosum found ?
# 20      location       what small island is northeast of trinidad ?
# 21      location           what city is located in the city of oz ?
# 22      location  what ' s the fifth - largest country in the wo...
# 23      location  where does the par shape of the medieval fish ...
# 24      location  what in the name of the planet that the ewoks ...
# 25      location  what asian gulf were the destroyers maddox and...
# 26      location  what u . s . city is known as the financial ca...
# 27      location  what country is the setting for edgar allan po...
# 28      location  what country is cawdor castle , glamis castle ...
# 29   description                      what is thermal equilibrium ?
# 30   description  how did the hohezollerns build their power aro...
# 31   description                         what happened to pompeii ?
# 32   description                             what is home banking ?
# 33   description                           what is an urban smirk ?
# 34   description  what was al capone finally imprisoned for , in...
# 35   description                          how do birds have wings ?
# 36   description  what was the v - 8 juice slogan : the ' the ta...
# 37   description                 why are there olive in martiniss ?
# 38   description  what is the history of spartacus , the roman s...
# 39        entity  what kind of patent did ermal arize obtain in ...
# 40        entity       which ear can most people hear better with ?
# 41        entity  name the french occupation period during the r...
# 42        entity           what determines the value of the value ?
# 43        entity         what language is mostly spoken in brazil ?
# 44        entity  what is the lens behind the iris in the eye ca...
# 45        entity                    what are halloween ' s colors ?
# 46        entity     in beetle eaton , can you name sarge ' s dog ?
# 47        entity  lineman fastener in whitcomb judson patent in ...
# 48        entity  what game do steve mcqueen and edward g . robi...
# 49  abbreviation                 what is the full name of the plo ?
# 50  abbreviation                                      what is dsh ?
# 51  abbreviation                         what does nasa stand for ?
# 52  abbreviation                          what does ekg stand for ?
# 53  abbreviation           what does ` ` o . y . o . b . ' ' mean ?
# 54  abbreviation  what is the abbreviated name of the national b...
# 55  abbreviation                          what does bud stand for ?
# 56  abbreviation  what is p . m . an abbreviation for , as in 10...
# 57  abbreviation  what is the abbreviation after the company nam...
# 58  abbreviation                        what does nafta stand for ?
